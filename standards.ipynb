# %%
import numpy as np
import pandas as pd

# %%
std = pd.read_csv("data/standards.tsv", skiprows=list(range(67)) + [68, 69], sep="|")

# %%
# mystar    18 22 22.3  -0 13 14  2000

# %%
fmt = "hip{0.HIP} {0.RAJ2000} {0.DEJ2000} 2000".format
data = "\n".join(map(fmt, (row for _, row in std.iterrows())))

# %%
with open("data/standards.list", "w") as f:
    f.write(data)

# %%
std[std.HIP == }]
# Out:
#         HIP      RAJ2000      DEJ2000  Vmag    B-V      SpType        Cat  \
# 1091  89282  18 13 07.18  +41 28 32.4  7.38  0.649  F8          ni,nor
#
#             RV      eRV      sRV  VC    N     e_RV  Tbase    JDm  Simbad  \
# 1091    -5.499   0.0157   0.0232  VC    8   0.0082   4765  52834  Simbad
#
#              _RA        _DE
# 1091  273.280108  41.475366

# %%
std.sort_values("Vmag")
# Out:
#          HIP      RAJ2000      DEJ2000   Vmag    B-V      SpType        Cat  \
# 1031   83601  17 05 16.83  +00 42 12.1   6.00  0.578  F9V         ni,nor
# 518    43726  08 54 18.19  -05 26 04.3   6.01  0.661  G3V         ni,nor
# 576    50174  10 14 29.84  +21 10 05.6   6.02  0.573  F9V         nor
# 842    69090  14 08 27.71  -74 51 02.6   6.02  0.581  G1V         nor
# 718    60599  12 25 15.07  +23 55 34.7   6.03  1.094  K0III       fa
# 1414  117880  23 54 38.34  -40 18 00.5   6.03  0.572  F8IV        nor
# 66      5936  01 16 18.90  +33 06 53.3   6.04  1.163  K1III       fa
# 415    33094  06 53 33.76  -28 32 19.4   6.05  0.708  G3/G5V      ni,nor
# 1407  117420  23 48 32.48  -06 22 49.4   6.09  1.452  K4III       IAU_std
# 1112   91606  18 40 56.40  +62 44 57.6   6.10  0.978  K0III       fa
# 717    60591  12 25 08.63  -42 30 51.3   6.10  0.652  G4IV        nor
# 1207  101507  20 34 11.66  -13 43 16.5   6.11  0.543  G0V         nor
# ...
